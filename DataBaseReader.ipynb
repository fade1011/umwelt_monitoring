# %%
import os
import json
import pandas as pd
from functools import reduce
import sqlite3
import pandas as pd
from tqdm import tqdm

# %%
weather_station_dict = {
    "601307eb571de9001b1b6c6c-WetterBrG_": 'WetterBrg',
    "617ab96c8b4e03001b05b489-_Wald_der_Zukunft__Stadtbergen": 'Wald der Zukunft - Stadtbergen',
    "633315b01ad7df001b349a76-PoS": 'PoS'
}

data_file_name = "data.csv"

renaming_dict = {
    "BeleuchtungsstÃ¤rke lx": "Licht Lux",
    "Luftdruck hPa": "Luftdruck hPa (=mBar)",
    "PM10 Âµg/mÂ³": "PM10 Âµm",
    "PM2.5 Âµg/mÂ³": "PM2.5 Âµm",
    "UV-IntensitÃ¤t Î¼W/cmÂ²": "UV Index"
}

column_dict = {
    "Temperatur Â°C": "Temperatur °C",
    "Bodentemperatur Â°C": "Bodentemperatur °C",
    "PM2.5 Âµm": "PM2.5 µm",
    "PM10 Âµm": "PM10 µm"
}

db_name = "sensor_daten.sqlite"

# %%
def get_assignment(assignment_path, file_paths): 
    assignment_dict = json.load(open(assignment_path))

    # With assingment
    sensor_names = assignment_dict.get("sensors")
    assignment = dict()
    for sensor in sensor_names:
        assignment[sensor.get('_id')] = {'title': sensor.get('title') + " " + sensor.get('unit')}

    for _id, _dict in assignment.items():
        for file in file_paths:
            if _id in file:
                _dict['file'] = file
                break

    return assignment

# %%
def create_database():
    """Create an SQLite database and table."""
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS WeatherData (
            createdAt TEXT,
            Temperatur REAL,
            rel_Luftfeuchte REAL,
            Luftdruck REAL,
            Bodenfeuchte REAL,
            Bodentemperatur REAL,
            Licht REAL,
            UV_Index REAL,
            PM25 REAL,
            PM10 REAL,
            station TEXT
        )''')
    
    conn.commit()
    conn.close()

def insert_dataframe_to_db(df, db_name):
    """Insert a pandas DataFrame into the SQLite database."""
    conn = sqlite3.connect(db_name)
    
    # Clean the DataFrame column names
    df.columns = [
        'createdAt', 'Temperatur', 'rel_Luftfeuchte', 'Luftdruck', 'Bodenfeuchte', 'Bodentemperatur',
        'Licht', 'UV_Index', 'PM25', 'PM10', 'station'
    ]

    # Insert the DataFrame into the SQLite table
    df.to_sql('WeatherData', conn, if_exists='append', index=False)

    conn.close()

# Create database if it doesnt exist
if not os.path.isfile(db_name):
    create_database()

# %%
# Todo find way to mark if its already finished
# 2023-12-06 fehlt im archiv

for day_folder in tqdm(os.listdir("./Data")):
    day = os.path.join("./Data", day_folder)
    # checking if it is a file
    if os.path.isfile(day):
        continue

    if os.path.isfile(os.path.join(day, data_file_name)):
        continue
    
    if not os.listdir(day):
        print(day, "date had no values")
        continue

    weather_station_day_data = []
    for weather_station in os.listdir(day):
        weather_data = os.path.join(day, weather_station)
        files = [os.path.join(weather_data, f) for f in os.listdir(weather_data) if (f.endswith(".csv") or f.endswith(".json"))]
        assignment = [f for f in files if f.endswith(".json")][0]
        files = [f for f in files if f.endswith(".csv")]
        measurements = get_assignment(assignment, files)
        data_frames = []
        for measurement in measurements.values():
            df = pd.read_csv(measurement['file'])
            df = df.rename(columns={'value': measurement['title']})
            data_frames.append(df)

        df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['createdAt'],
                                        how='outer'), data_frames)

        df_merged['station'] = weather_station_dict[weather_station]
        df_merged = df_merged.rename(columns=renaming_dict)
        weather_station_day_data.append(df_merged)
    
    df_concat = pd.concat(weather_station_day_data)
    df_concat = df_concat.rename(columns=column_dict)
    insert_dataframe_to_db(df_concat, db_name)
    df_concat.to_csv(os.path.join(day, data_file_name), index=False)
# Out:
#  68%|██████▊   | 434/634 [02:09<01:11,  2.79it/s]
# ./Data\2023-12-06 date had no values
#  72%|███████▏  | 455/634 [02:12<00:15, 11.35it/s]
# ./Data\2023-12-25 date had no values
#  73%|███████▎  | 463/634 [02:13<00:15, 10.76it/s]
# ./Data\2024-01-02 date had no values
#  75%|███████▍  | 474/634 [02:14<00:15, 10.41it/s]
# ./Data\2024-01-13 date had no values
#  76%|███████▋  | 484/634 [02:15<00:14, 10.22it/s]
# ./Data\2024-01-23 date had no values
#  82%|████████▏ | 517/634 [02:21<00:11, 10.15it/s]
# ./Data\2024-02-25 date had no values
#  93%|█████████▎| 587/634 [02:34<00:02, 18.21it/s]
# ./Data\2024-05-02 date had no values
# ./Data\2024-05-03 date had no values
# ./Data\2024-05-04 date had no values
# ./Data\2024-05-05 date had no values
#  93%|█████████▎| 589/634 [02:34<00:02, 18.05it/s]
# ./Data\2024-05-08 date had no values
#  93%|█████████▎| 591/634 [02:34<00:02, 14.46it/s]
# ./Data\2024-05-10 date had no values
# ./Data\2024-05-11 date had no values
#  94%|█████████▍| 597/634 [02:35<00:07,  5.14it/s]
# ./Data\2024-05-17 date had no values
# ./Data\2024-05-18 date had no values
#  95%|█████████▌| 604/634 [02:37<00:08,  3.43it/s]
# ./Data\2024-05-24 date had no values
# ./Data\2024-05-25 date had no values
# 100%|██████████| 634/634 [02:47<00:00,  3.80it/s]

# %%
df_concat
# Out:
#                      createdAt  Temperatur  rel_Luftfeuchte  Luftdruck  \
# 0     2024-06-22T00:00:23.302Z       13.19            94.68    1017.61
# 1     2024-06-22T00:01:23.288Z       13.22            94.88    1017.58
# 2     2024-06-22T00:02:23.281Z       13.25            95.39    1017.58
# 3     2024-06-22T00:03:23.420Z       13.30            95.18    1017.63
# 4     2024-06-22T00:04:23.427Z       13.31            95.39    1017.61
# ...                        ...         ...              ...        ...
# 1433  2024-06-22T23:55:20.649Z       15.92            90.40     982.90
# 1434  2024-06-22T23:56:20.655Z       15.90            90.40     982.89
# 1435  2024-06-22T23:57:20.631Z       15.92            90.60     982.89
# 1436  2024-06-22T23:58:20.628Z       15.92            90.60     982.89
# 1437  2024-06-22T23:59:20.605Z       15.90            90.60     982.89
#
#       Bodenfeuchte  Bodentemperatur  Licht  UV_Index  PM25  PM10    station
# 0            19.98            15.74    0.0       0.0  12.1   6.6  WetterBrg
# 1            20.41            21.54    0.0       0.0  12.8   8.2  WetterBrg
# 2            20.03             8.33    0.0       0.0  12.1   8.2  WetterBrg
# 3            20.84            23.80    0.0       0.0  11.1   7.1  WetterBrg
# 4            20.09             5.75    0.0       0.0  13.6   7.8  WetterBrg
# ...            ...              ...    ...       ...   ...   ...        ...
# 1433         11.33            22.51    0.0       0.0   2.1   5.7        PoS
# 1434         11.12            16.39    0.0       0.0   1.6   4.0        PoS
# 1435         11.12            17.03    0.0       0.0   1.9   4.6        PoS
# 1436         11.12            16.39    0.0       0.0   1.7   4.4        PoS
# 1437         12.41            24.77    0.0       0.0   2.0   5.0        PoS
#
# [2878 rows x 11 columns]

# %%
"""Fetch a limited number of rows from the specified table in the SQLite database."""
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

cursor.execute(f"SELECT * FROM WeatherData LIMIT {3}")
rows = cursor.fetchall()

conn.close()
rows
# Out:
# [('2022-09-28T00:00:40.694Z',
#   7.96,
#   99.99,
#   998.76,
#   26.0,
#   17.68,
#   0.0,
#   0.0,
#   6.6,
#   1.4,
#   'WetterBrg'),
#  ('2022-09-28T00:01:40.707Z',
#   7.95,
#   99.99,
#   998.82,
#   26.1,
#   10.26,
#   0.0,
#   0.0,
#   3.1,
#   1.3,
#   'WetterBrg'),
#  ('2022-09-28T00:02:40.751Z',
#   7.95,
#   99.99,
#   998.82,
#   25.78,
#   10.59,
#   0.0,
#   0.0,
#   3.4,
#   1.3,
#   'WetterBrg')]

# %%
for foldername, subfolders, filenames in os.walk("./Data"):
        for filename in filenames:
            if filename == 'data.csv':
                file_path = os.path.join(foldername, filename)
                try:
                    os.remove(file_path)
                    print(f"Deleted: {file_path}")
                except Exception as e:
                    print(f"Failed to delete {file_path}: {e}")
# Out:
# Deleted: ./Data\2022-09-28\data.csv
# Deleted: ./Data\2022-09-29\data.csv
# Deleted: ./Data\2022-09-30\data.csv
# Deleted: ./Data\2022-10-01\data.csv
# Deleted: ./Data\2022-10-02\data.csv
# Deleted: ./Data\2022-10-03\data.csv
# Deleted: ./Data\2022-10-04\data.csv
# Deleted: ./Data\2022-10-05\data.csv
# Deleted: ./Data\2022-10-06\data.csv
# Deleted: ./Data\2022-10-07\data.csv
# Deleted: ./Data\2022-10-08\data.csv
# Deleted: ./Data\2022-10-09\data.csv
# Deleted: ./Data\2022-10-10\data.csv
# Deleted: ./Data\2022-10-11\data.csv
# Deleted: ./Data\2022-10-12\data.csv
# Deleted: ./Data\2022-10-13\data.csv
# Deleted: ./Data\2022-10-14\data.csv
# Deleted: ./Data\2022-10-15\data.csv
# Deleted: ./Data\2022-10-16\data.csv
# Deleted: ./Data\2022-10-17\data.csv
# Deleted: ./Data\2022-10-18\data.csv
# Deleted: ./Data\2022-10-19\data.csv
# Deleted: ./Data\2022-10-20\data.csv
# Deleted: ./Data\2022-10-21\data.csv
# Deleted: ./Data\2022-10-22\data.csv
# Deleted: ./Data\2022-10-23\data.csv
# Deleted: ./Data\2022-10-24\data.csv
# Deleted: ./Data\2022-10-25\data.csv
# Deleted: ./Data\2022-10-26\data.csv
# Deleted: ./Data\2022-10-27\data.csv
# Deleted: ./Data\2022-10-28\data.csv
# Deleted: ./Data\2022-10-29\data.csv
# Deleted: ./Data\2022-10-30\data.csv
# Deleted: ./Data\2022-10-31\data.csv
# Deleted: ./Data\2022-11-01\data.csv
# Deleted: ./Data\2022-11-02\data.csv
# Deleted: ./Data\2022-11-03\data.csv
# Deleted: ./Data\2022-11-04\data.csv
# Deleted: ./Data\2022-11-05\data.csv
# Deleted: ./Data\2022-11-06\data.csv
# Deleted: ./Data\2022-11-07\data.csv
# Deleted: ./Data\2022-11-08\data.csv
# Deleted: ./Data\2022-11-09\data.csv
# Deleted: ./Data\2022-11-10\data.csv
# Deleted: ./Data\2022-11-11\data.csv
# Deleted: ./Data\2022-11-12\data.csv
# Deleted: ./Data\2022-11-13\data.csv
# Deleted: ./Data\2022-11-14\data.csv
# Deleted: ./Data\2022-11-15\data.csv
# Deleted: ./Data\2022-11-16\data.csv
# Deleted: ./Data\2022-11-17\data.csv
# Deleted: ./Data\2022-11-18\data.csv
# Deleted: ./Data\2022-11-19\data.csv
# Deleted: ./Data\2022-11-20\data.csv
# Deleted: ./Data\2022-11-21\data.csv
# Deleted: ./Data\2022-11-22\data.csv
# Deleted: ./Data\2022-11-23\data.csv
# Deleted: ./Data\2022-11-24\data.csv
# Deleted: ./Data\2022-11-25\data.csv
# Deleted: ./Data\2022-11-26\data.csv
# Deleted: ./Data\2022-11-27\data.csv
# Deleted: ./Data\2022-11-28\data.csv
# Deleted: ./Data\2022-11-29\data.csv
# Deleted: ./Data\2022-11-30\data.csv
# Deleted: ./Data\2022-12-01\data.csv
# Deleted: ./Data\2022-12-02\data.csv
# Deleted: ./Data\2022-12-03\data.csv
# Deleted: ./Data\2022-12-04\data.csv
# Deleted: ./Data\2022-12-05\data.csv
# Deleted: ./Data\2022-12-06\data.csv
# Deleted: ./Data\2022-12-07\data.csv
# Deleted: ./Data\2022-12-08\data.csv
# Deleted: ./Data\2022-12-09\data.csv
# Deleted: ./Data\2022-12-10\data.csv
# Deleted: ./Data\2022-12-11\data.csv
# Deleted: ./Data\2022-12-12\data.csv
# Deleted: ./Data\2022-12-13\data.csv
# Deleted: ./Data\2022-12-14\data.csv
# Deleted: ./Data\2022-12-15\data.csv
# Deleted: ./Data\2022-12-16\data.csv
# Deleted: ./Data\2022-12-17\data.csv
# Deleted: ./Data\2022-12-18\data.csv
# Deleted: ./Data\2022-12-19\data.csv
# Deleted: ./Data\2022-12-20\data.csv
# Deleted: ./Data\2022-12-21\data.csv
# Deleted: ./Data\2022-12-22\data.csv
# Deleted: ./Data\2022-12-23\data.csv
# Deleted: ./Data\2022-12-24\data.csv
# Deleted: ./Data\2022-12-25\data.csv
# Deleted: ./Data\2022-12-26\data.csv
# Deleted: ./Data\2022-12-27\data.csv
# Deleted: ./Data\2022-12-28\data.csv
# Deleted: ./Data\2022-12-29\data.csv
# Deleted: ./Data\2022-12-30\data.csv
# Deleted: ./Data\2022-12-31\data.csv
# Deleted: ./Data\2023-01-01\data.csv
# Deleted: ./Data\2023-01-02\data.csv
# Deleted: ./Data\2023-01-03\data.csv
# Deleted: ./Data\2023-01-04\data.csv
# Deleted: ./Data\2023-01-05\data.csv
# Deleted: ./Data\2023-01-06\data.csv
# Deleted: ./Data\2023-01-07\data.csv
# Deleted: ./Data\2023-01-08\data.csv
# Deleted: ./Data\2023-01-09\data.csv
# Deleted: ./Data\2023-01-10\data.csv
# Deleted: ./Data\2023-01-11\data.csv
# Deleted: ./Data\2023-01-12\data.csv
# Deleted: ./Data\2023-01-13\data.csv
# Deleted: ./Data\2023-01-14\data.csv
# Deleted: ./Data\2023-01-15\data.csv
# Deleted: ./Data\2023-01-16\data.csv
# Deleted: ./Data\2023-01-17\data.csv
# Deleted: ./Data\2023-01-18\data.csv
# Deleted: ./Data\2023-01-19\data.csv
# Deleted: ./Data\2023-01-20\data.csv
# Deleted: ./Data\2023-01-21\data.csv
# Deleted: ./Data\2023-01-22\data.csv
# Deleted: ./Data\2023-01-23\data.csv
# Deleted: ./Data\2023-01-24\data.csv
# Deleted: ./Data\2023-01-25\data.csv
# Deleted: ./Data\2023-01-26\data.csv
# Deleted: ./Data\2023-01-27\data.csv
# Deleted: ./Data\2023-01-28\data.csv
# Deleted: ./Data\2023-01-29\data.csv
# Deleted: ./Data\2023-01-30\data.csv
# Deleted: ./Data\2023-01-31\data.csv
# Deleted: ./Data\2023-02-01\data.csv
# Deleted: ./Data\2023-02-02\data.csv
# Deleted: ./Data\2023-02-03\data.csv
# Deleted: ./Data\2023-02-04\data.csv
# Deleted: ./Data\2023-02-05\data.csv
# Deleted: ./Data\2023-02-06\data.csv
# Deleted: ./Data\2023-02-07\data.csv
# Deleted: ./Data\2023-02-08\data.csv
# Deleted: ./Data\2023-02-09\data.csv
# Deleted: ./Data\2023-02-10\data.csv
# Deleted: ./Data\2023-02-11\data.csv
# Deleted: ./Data\2023-02-12\data.csv
# Deleted: ./Data\2023-02-13\data.csv
# Deleted: ./Data\2023-02-14\data.csv
# Deleted: ./Data\2023-02-15\data.csv
# Deleted: ./Data\2023-02-16\data.csv
# Deleted: ./Data\2023-02-17\data.csv
# Deleted: ./Data\2023-02-18\data.csv
# Deleted: ./Data\2023-02-19\data.csv
# Deleted: ./Data\2023-02-20\data.csv
# Deleted: ./Data\2023-02-21\data.csv
# Deleted: ./Data\2023-02-22\data.csv
# Deleted: ./Data\2023-02-23\data.csv
# Deleted: ./Data\2023-02-24\data.csv
# Deleted: ./Data\2023-02-25\data.csv
# Deleted: ./Data\2023-02-26\data.csv
# Deleted: ./Data\2023-02-27\data.csv
# Deleted: ./Data\2023-02-28\data.csv
# Deleted: ./Data\2023-03-01\data.csv
# Deleted: ./Data\2023-03-02\data.csv
# Deleted: ./Data\2023-03-03\data.csv
# Deleted: ./Data\2023-03-04\data.csv
# Deleted: ./Data\2023-03-05\data.csv
# Deleted: ./Data\2023-03-06\data.csv
# Deleted: ./Data\2023-03-07\data.csv
# Deleted: ./Data\2023-03-08\data.csv
# Deleted: ./Data\2023-03-09\data.csv
# Deleted: ./Data\2023-03-10\data.csv
# Deleted: ./Data\2023-03-11\data.csv
# Deleted: ./Data\2023-03-12\data.csv
# Deleted: ./Data\2023-03-13\data.csv
# Deleted: ./Data\2023-03-14\data.csv
# Deleted: ./Data\2023-03-15\data.csv
# Deleted: ./Data\2023-03-16\data.csv
# Deleted: ./Data\2023-03-17\data.csv
# Deleted: ./Data\2023-03-18\data.csv
# Deleted: ./Data\2023-03-19\data.csv
# Deleted: ./Data\2023-03-20\data.csv
# Deleted: ./Data\2023-03-21\data.csv
# Deleted: ./Data\2023-03-22\data.csv
# Deleted: ./Data\2023-03-23\data.csv
# Deleted: ./Data\2023-03-24\data.csv
# Deleted: ./Data\2023-03-25\data.csv
# Deleted: ./Data\2023-03-26\data.csv
# Deleted: ./Data\2023-03-27\data.csv
# Deleted: ./Data\2023-03-28\data.csv
# Deleted: ./Data\2023-03-29\data.csv
# Deleted: ./Data\2023-03-30\data.csv
# Deleted: ./Data\2023-03-31\data.csv
# Deleted: ./Data\2023-04-01\data.csv
# Deleted: ./Data\2023-04-02\data.csv
# Deleted: ./Data\2023-04-03\data.csv
# Deleted: ./Data\2023-04-04\data.csv
# Deleted: ./Data\2023-04-05\data.csv
# Deleted: ./Data\2023-04-06\data.csv
# Deleted: ./Data\2023-04-07\data.csv
# Deleted: ./Data\2023-04-08\data.csv
# Deleted: ./Data\2023-04-09\data.csv
# Deleted: ./Data\2023-04-10\data.csv
# Deleted: ./Data\2023-04-11\data.csv
# Deleted: ./Data\2023-04-12\data.csv
# Deleted: ./Data\2023-04-13\data.csv
# Deleted: ./Data\2023-04-14\data.csv
# Deleted: ./Data\2023-04-15\data.csv
# Deleted: ./Data\2023-04-16\data.csv
# Deleted: ./Data\2023-04-17\data.csv
# Deleted: ./Data\2023-04-18\data.csv
# Deleted: ./Data\2023-04-19\data.csv
# Deleted: ./Data\2023-04-20\data.csv
# Deleted: ./Data\2023-04-21\data.csv
# Deleted: ./Data\2023-04-22\data.csv
# Deleted: ./Data\2023-04-23\data.csv
# Deleted: ./Data\2023-04-24\data.csv
# Deleted: ./Data\2023-04-25\data.csv
# Deleted: ./Data\2023-04-26\data.csv
# Deleted: ./Data\2023-04-27\data.csv
# Deleted: ./Data\2023-04-28\data.csv
# Deleted: ./Data\2023-04-29\data.csv
# Deleted: ./Data\2023-04-30\data.csv
# Deleted: ./Data\2023-05-01\data.csv
# Deleted: ./Data\2023-05-02\data.csv
# Deleted: ./Data\2023-05-03\data.csv
# Deleted: ./Data\2023-05-04\data.csv
# Deleted: ./Data\2023-05-05\data.csv
# Deleted: ./Data\2023-05-06\data.csv
# Deleted: ./Data\2023-05-07\data.csv
# Deleted: ./Data\2023-05-08\data.csv
# Deleted: ./Data\2023-05-09\data.csv
# Deleted: ./Data\2023-05-10\data.csv
# Deleted: ./Data\2023-05-11\data.csv
# Deleted: ./Data\2023-05-12\data.csv
# Deleted: ./Data\2023-05-13\data.csv
# Deleted: ./Data\2023-05-14\data.csv
# Deleted: ./Data\2023-05-15\data.csv
# Deleted: ./Data\2023-05-16\data.csv
# Deleted: ./Data\2023-05-17\data.csv
# Deleted: ./Data\2023-05-18\data.csv
# Deleted: ./Data\2023-05-19\data.csv
# Deleted: ./Data\2023-05-20\data.csv
# Deleted: ./Data\2023-05-21\data.csv
# Deleted: ./Data\2023-05-22\data.csv
# Deleted: ./Data\2023-05-23\data.csv
# Deleted: ./Data\2023-05-24\data.csv
# Deleted: ./Data\2023-05-25\data.csv
# Deleted: ./Data\2023-05-26\data.csv
# Deleted: ./Data\2023-05-27\data.csv
# Deleted: ./Data\2023-05-28\data.csv
# Deleted: ./Data\2023-05-29\data.csv
# Deleted: ./Data\2023-05-30\data.csv
# Deleted: ./Data\2023-05-31\data.csv
# Deleted: ./Data\2023-06-01\data.csv
# Deleted: ./Data\2023-06-02\data.csv
# Deleted: ./Data\2023-06-03\data.csv
# Deleted: ./Data\2023-06-04\data.csv
# Deleted: ./Data\2023-06-05\data.csv
# Deleted: ./Data\2023-06-06\data.csv
# Deleted: ./Data\2023-06-07\data.csv
# Deleted: ./Data\2023-06-08\data.csv
# Deleted: ./Data\2023-06-09\data.csv
# Deleted: ./Data\2023-06-10\data.csv
# Deleted: ./Data\2023-06-11\data.csv
# Deleted: ./Data\2023-06-12\data.csv
# Deleted: ./Data\2023-06-13\data.csv
# Deleted: ./Data\2023-06-14\data.csv
# Deleted: ./Data\2023-06-15\data.csv
# Deleted: ./Data\2023-06-16\data.csv
# Deleted: ./Data\2023-06-17\data.csv
# Deleted: ./Data\2023-06-18\data.csv
# Deleted: ./Data\2023-06-19\data.csv
# Deleted: ./Data\2023-06-20\data.csv
# Deleted: ./Data\2023-06-21\data.csv
# Deleted: ./Data\2023-06-22\data.csv
# Deleted: ./Data\2023-06-23\data.csv
# Deleted: ./Data\2023-06-24\data.csv
# Deleted: ./Data\2023-06-25\data.csv
# Deleted: ./Data\2023-06-26\data.csv
# Deleted: ./Data\2023-06-27\data.csv
# Deleted: ./Data\2023-06-28\data.csv
# Deleted: ./Data\2023-06-29\data.csv
# Deleted: ./Data\2023-06-30\data.csv
# Deleted: ./Data\2023-07-01\data.csv
# Deleted: ./Data\2023-07-02\data.csv
# Deleted: ./Data\2023-07-03\data.csv
# Deleted: ./Data\2023-07-04\data.csv
# Deleted: ./Data\2023-07-05\data.csv
# Deleted: ./Data\2023-07-06\data.csv
# Deleted: ./Data\2023-07-07\data.csv
# Deleted: ./Data\2023-07-08\data.csv
# Deleted: ./Data\2023-07-09\data.csv
# Deleted: ./Data\2023-07-10\data.csv
# Deleted: ./Data\2023-07-11\data.csv
# Deleted: ./Data\2023-07-12\data.csv
# Deleted: ./Data\2023-07-13\data.csv
# Deleted: ./Data\2023-07-14\data.csv
# Deleted: ./Data\2023-07-15\data.csv
# Deleted: ./Data\2023-07-16\data.csv
# Deleted: ./Data\2023-07-17\data.csv
# Deleted: ./Data\2023-07-18\data.csv
# Deleted: ./Data\2023-07-19\data.csv
# Deleted: ./Data\2023-07-20\data.csv
# Deleted: ./Data\2023-07-21\data.csv
# Deleted: ./Data\2023-07-22\data.csv
# Deleted: ./Data\2023-07-23\data.csv
# Deleted: ./Data\2023-07-24\data.csv
# Deleted: ./Data\2023-07-25\data.csv
# Deleted: ./Data\2023-07-26\data.csv
# Deleted: ./Data\2023-07-27\data.csv
# Deleted: ./Data\2023-07-28\data.csv
# Deleted: ./Data\2023-07-29\data.csv
# Deleted: ./Data\2023-07-30\data.csv
# Deleted: ./Data\2023-07-31\data.csv
# Deleted: ./Data\2023-08-01\data.csv
# Deleted: ./Data\2023-08-02\data.csv
# Deleted: ./Data\2023-08-03\data.csv
# Deleted: ./Data\2023-08-04\data.csv
# Deleted: ./Data\2023-08-05\data.csv
# Deleted: ./Data\2023-08-06\data.csv
# Deleted: ./Data\2023-08-07\data.csv
# Deleted: ./Data\2023-08-08\data.csv
# Deleted: ./Data\2023-08-09\data.csv
# Deleted: ./Data\2023-08-10\data.csv
# Deleted: ./Data\2023-08-11\data.csv
# Deleted: ./Data\2023-08-12\data.csv
# Deleted: ./Data\2023-08-13\data.csv
# Deleted: ./Data\2023-08-14\data.csv
# Deleted: ./Data\2023-08-15\data.csv
# Deleted: ./Data\2023-08-16\data.csv
# Deleted: ./Data\2023-08-17\data.csv
# Deleted: ./Data\2023-08-18\data.csv
# Deleted: ./Data\2023-08-19\data.csv
# Deleted: ./Data\2023-08-20\data.csv
# Deleted: ./Data\2023-08-21\data.csv
# Deleted: ./Data\2023-08-22\data.csv
# Deleted: ./Data\2023-08-23\data.csv
# Deleted: ./Data\2023-08-24\data.csv
# Deleted: ./Data\2023-08-25\data.csv
# Deleted: ./Data\2023-08-26\data.csv
# Deleted: ./Data\2023-08-27\data.csv
# Deleted: ./Data\2023-08-28\data.csv
# Deleted: ./Data\2023-08-29\data.csv
# Deleted: ./Data\2023-08-30\data.csv
# Deleted: ./Data\2023-08-31\data.csv
# Deleted: ./Data\2023-09-01\data.csv
# Deleted: ./Data\2023-09-02\data.csv
# Deleted: ./Data\2023-09-03\data.csv
# Deleted: ./Data\2023-09-04\data.csv
# Deleted: ./Data\2023-09-05\data.csv
# Deleted: ./Data\2023-09-06\data.csv
# Deleted: ./Data\2023-09-07\data.csv
# Deleted: ./Data\2023-09-08\data.csv
# Deleted: ./Data\2023-09-09\data.csv
# Deleted: ./Data\2023-09-10\data.csv
# Deleted: ./Data\2023-09-11\data.csv
# Deleted: ./Data\2023-09-12\data.csv
# Deleted: ./Data\2023-09-13\data.csv
# Deleted: ./Data\2023-09-14\data.csv
# Deleted: ./Data\2023-09-15\data.csv
# Deleted: ./Data\2023-09-16\data.csv
# Deleted: ./Data\2023-09-17\data.csv
# Deleted: ./Data\2023-09-18\data.csv
# Deleted: ./Data\2023-09-19\data.csv
# Deleted: ./Data\2023-09-20\data.csv
# Deleted: ./Data\2023-09-21\data.csv
# Deleted: ./Data\2023-09-22\data.csv
# Deleted: ./Data\2023-09-23\data.csv
# Deleted: ./Data\2023-09-24\data.csv
# Deleted: ./Data\2023-09-25\data.csv
# Deleted: ./Data\2023-09-26\data.csv
# Deleted: ./Data\2023-09-27\data.csv
# Deleted: ./Data\2023-09-28\data.csv
# Deleted: ./Data\2023-09-29\data.csv
# Deleted: ./Data\2023-09-30\data.csv
# Deleted: ./Data\2023-10-01\data.csv
# Deleted: ./Data\2023-10-02\data.csv
# Deleted: ./Data\2023-10-03\data.csv
# Deleted: ./Data\2023-10-04\data.csv
# Deleted: ./Data\2023-10-05\data.csv
# Deleted: ./Data\2023-10-06\data.csv
# Deleted: ./Data\2023-10-07\data.csv
# Deleted: ./Data\2023-10-08\data.csv
# Deleted: ./Data\2023-10-09\data.csv
# Deleted: ./Data\2023-10-10\data.csv
# Deleted: ./Data\2023-10-11\data.csv
# Deleted: ./Data\2023-10-12\data.csv
# Deleted: ./Data\2023-10-13\data.csv
# Deleted: ./Data\2023-10-14\data.csv
# Deleted: ./Data\2023-10-15\data.csv
# Deleted: ./Data\2023-10-16\data.csv
# Deleted: ./Data\2023-10-17\data.csv
# Deleted: ./Data\2023-10-18\data.csv
# Deleted: ./Data\2023-10-19\data.csv
# Deleted: ./Data\2023-10-20\data.csv
# Deleted: ./Data\2023-10-21\data.csv
# Deleted: ./Data\2023-10-22\data.csv
# Deleted: ./Data\2023-10-23\data.csv
# Deleted: ./Data\2023-10-24\data.csv
# Deleted: ./Data\2023-10-25\data.csv
# Deleted: ./Data\2023-10-26\data.csv
# Deleted: ./Data\2023-10-27\data.csv
# Deleted: ./Data\2023-10-28\data.csv
# Deleted: ./Data\2023-10-29\data.csv
# Deleted: ./Data\2023-10-30\data.csv
# Deleted: ./Data\2023-10-31\data.csv
# Deleted: ./Data\2023-11-01\data.csv
# Deleted: ./Data\2023-11-02\data.csv
# Deleted: ./Data\2023-11-03\data.csv
# Deleted: ./Data\2023-11-04\data.csv
# Deleted: ./Data\2023-11-05\data.csv
# Deleted: ./Data\2023-11-06\data.csv
# Deleted: ./Data\2023-11-07\data.csv
# Deleted: ./Data\2023-11-08\data.csv
# Deleted: ./Data\2023-11-09\data.csv
# Deleted: ./Data\2023-11-10\data.csv
# Deleted: ./Data\2023-11-11\data.csv
# Deleted: ./Data\2023-11-12\data.csv
# Deleted: ./Data\2023-11-13\data.csv
# Deleted: ./Data\2023-11-14\data.csv
# Deleted: ./Data\2023-11-15\data.csv
# Deleted: ./Data\2023-11-16\data.csv
# Deleted: ./Data\2023-11-17\data.csv
# Deleted: ./Data\2023-11-18\data.csv
# Deleted: ./Data\2023-11-19\data.csv
# Deleted: ./Data\2023-11-20\data.csv
# Deleted: ./Data\2023-11-21\data.csv
# Deleted: ./Data\2023-11-22\data.csv
# Deleted: ./Data\2023-11-23\data.csv
# Deleted: ./Data\2023-11-24\data.csv
# Deleted: ./Data\2023-11-25\data.csv
# Deleted: ./Data\2023-11-26\data.csv
# Deleted: ./Data\2023-11-27\data.csv
# Deleted: ./Data\2023-11-28\data.csv
# Deleted: ./Data\2023-11-29\data.csv
# Deleted: ./Data\2023-11-30\data.csv
# Deleted: ./Data\2023-12-01\data.csv
# Deleted: ./Data\2023-12-02\data.csv
# Deleted: ./Data\2023-12-03\data.csv
# Deleted: ./Data\2023-12-04\data.csv
# Deleted: ./Data\2023-12-05\data.csv
# Deleted: ./Data\2023-12-07\data.csv
# Deleted: ./Data\2023-12-08\data.csv
# Deleted: ./Data\2023-12-09\data.csv
# Deleted: ./Data\2023-12-10\data.csv
# Deleted: ./Data\2023-12-11\data.csv
# Deleted: ./Data\2023-12-12\data.csv
# Deleted: ./Data\2023-12-13\data.csv
# Deleted: ./Data\2023-12-14\data.csv
# Deleted: ./Data\2023-12-15\data.csv
# Deleted: ./Data\2023-12-16\data.csv
# Deleted: ./Data\2023-12-17\data.csv
# Deleted: ./Data\2023-12-18\data.csv
# Deleted: ./Data\2023-12-19\data.csv
# Deleted: ./Data\2023-12-20\data.csv
# Deleted: ./Data\2023-12-21\data.csv
# Deleted: ./Data\2023-12-22\data.csv
# Deleted: ./Data\2023-12-23\data.csv
# Deleted: ./Data\2023-12-24\data.csv
# Deleted: ./Data\2023-12-26\data.csv
# Deleted: ./Data\2023-12-27\data.csv
# Deleted: ./Data\2023-12-28\data.csv
# Deleted: ./Data\2023-12-29\data.csv
# Deleted: ./Data\2023-12-30\data.csv
# Deleted: ./Data\2023-12-31\data.csv
# Deleted: ./Data\2024-01-01\data.csv
# Deleted: ./Data\2024-01-03\data.csv
# Deleted: ./Data\2024-01-04\data.csv
# Deleted: ./Data\2024-01-05\data.csv
# Deleted: ./Data\2024-01-06\data.csv
# Deleted: ./Data\2024-01-07\data.csv
# Deleted: ./Data\2024-01-08\data.csv
# Deleted: ./Data\2024-01-09\data.csv
# Deleted: ./Data\2024-01-10\data.csv
# Deleted: ./Data\2024-01-11\data.csv
# Deleted: ./Data\2024-01-12\data.csv
# Deleted: ./Data\2024-01-14\data.csv
# Deleted: ./Data\2024-01-15\data.csv
# Deleted: ./Data\2024-01-16\data.csv
# Deleted: ./Data\2024-01-17\data.csv
# Deleted: ./Data\2024-01-18\data.csv
# Deleted: ./Data\2024-01-19\data.csv
# Deleted: ./Data\2024-01-20\data.csv
# Deleted: ./Data\2024-01-21\data.csv
# Deleted: ./Data\2024-01-22\data.csv
# Deleted: ./Data\2024-01-24\data.csv
# Deleted: ./Data\2024-01-25\data.csv
# Deleted: ./Data\2024-01-26\data.csv
# Deleted: ./Data\2024-01-27\data.csv
# Deleted: ./Data\2024-01-28\data.csv
# Deleted: ./Data\2024-01-29\data.csv
# Deleted: ./Data\2024-01-30\data.csv
# Deleted: ./Data\2024-01-31\data.csv
# Deleted: ./Data\2024-02-01\data.csv
# Deleted: ./Data\2024-02-02\data.csv
# Deleted: ./Data\2024-02-03\data.csv
# Deleted: ./Data\2024-02-04\data.csv
# Deleted: ./Data\2024-02-05\data.csv
# Deleted: ./Data\2024-02-06\data.csv
# Deleted: ./Data\2024-02-07\data.csv
# Deleted: ./Data\2024-02-08\data.csv
# Deleted: ./Data\2024-02-09\data.csv
# Deleted: ./Data\2024-02-10\data.csv
# Deleted: ./Data\2024-02-11\data.csv
# Deleted: ./Data\2024-02-12\data.csv
# Deleted: ./Data\2024-02-13\data.csv
# Deleted: ./Data\2024-02-14\data.csv
# Deleted: ./Data\2024-02-15\data.csv
# Deleted: ./Data\2024-02-16\data.csv
# Deleted: ./Data\2024-02-17\data.csv
# Deleted: ./Data\2024-02-18\data.csv
# Deleted: ./Data\2024-02-19\data.csv
# Deleted: ./Data\2024-02-20\data.csv
# Deleted: ./Data\2024-02-21\data.csv
# Deleted: ./Data\2024-02-22\data.csv
# Deleted: ./Data\2024-02-23\data.csv
# Deleted: ./Data\2024-02-24\data.csv
# Deleted: ./Data\2024-02-26\data.csv
# Deleted: ./Data\2024-02-27\data.csv
# Deleted: ./Data\2024-02-28\data.csv
# Deleted: ./Data\2024-02-29\data.csv
# Deleted: ./Data\2024-03-01\data.csv
# Deleted: ./Data\2024-03-02\data.csv
# Deleted: ./Data\2024-03-03\data.csv
# Deleted: ./Data\2024-03-04\data.csv
# Deleted: ./Data\2024-03-05\data.csv
# Deleted: ./Data\2024-03-06\data.csv
# Deleted: ./Data\2024-03-07\data.csv
# Deleted: ./Data\2024-03-08\data.csv
# Deleted: ./Data\2024-03-09\data.csv
# Deleted: ./Data\2024-03-10\data.csv
# Deleted: ./Data\2024-03-11\data.csv
# Deleted: ./Data\2024-03-12\data.csv
# Deleted: ./Data\2024-03-13\data.csv
# Deleted: ./Data\2024-03-14\data.csv
# Deleted: ./Data\2024-03-15\data.csv
# Deleted: ./Data\2024-03-16\data.csv
# Deleted: ./Data\2024-03-17\data.csv
# Deleted: ./Data\2024-03-18\data.csv
# Deleted: ./Data\2024-03-19\data.csv
# Deleted: ./Data\2024-03-20\data.csv
# Deleted: ./Data\2024-03-21\data.csv
# Deleted: ./Data\2024-03-22\data.csv
# Deleted: ./Data\2024-03-23\data.csv
# Deleted: ./Data\2024-03-24\data.csv
# Deleted: ./Data\2024-03-25\data.csv
# Deleted: ./Data\2024-03-26\data.csv
# Deleted: ./Data\2024-03-27\data.csv
# Deleted: ./Data\2024-03-28\data.csv
# Deleted: ./Data\2024-03-29\data.csv
# Deleted: ./Data\2024-03-30\data.csv
# Deleted: ./Data\2024-03-31\data.csv
# Deleted: ./Data\2024-04-01\data.csv
# Deleted: ./Data\2024-04-02\data.csv
# Deleted: ./Data\2024-04-03\data.csv
# Deleted: ./Data\2024-04-04\data.csv
# Deleted: ./Data\2024-04-05\data.csv
# Deleted: ./Data\2024-04-06\data.csv
# Deleted: ./Data\2024-04-07\data.csv
# Deleted: ./Data\2024-04-08\data.csv
# Deleted: ./Data\2024-04-09\data.csv
# Deleted: ./Data\2024-04-10\data.csv
# Deleted: ./Data\2024-04-11\data.csv
# Deleted: ./Data\2024-04-12\data.csv
# Deleted: ./Data\2024-04-13\data.csv
# Deleted: ./Data\2024-04-14\data.csv
# Deleted: ./Data\2024-04-15\data.csv
# Deleted: ./Data\2024-04-16\data.csv
# Deleted: ./Data\2024-04-17\data.csv
# Deleted: ./Data\2024-04-18\data.csv
# Deleted: ./Data\2024-04-19\data.csv
# Deleted: ./Data\2024-04-20\data.csv
# Deleted: ./Data\2024-04-21\data.csv
# Deleted: ./Data\2024-04-22\data.csv
# Deleted: ./Data\2024-04-23\data.csv
# Deleted: ./Data\2024-04-24\data.csv
# Deleted: ./Data\2024-04-25\data.csv
# Deleted: ./Data\2024-04-26\data.csv
# Deleted: ./Data\2024-04-27\data.csv
# Deleted: ./Data\2024-04-28\data.csv
# Deleted: ./Data\2024-04-29\data.csv
# Deleted: ./Data\2024-04-30\data.csv
# Deleted: ./Data\2024-05-01\data.csv
# Deleted: ./Data\2024-05-06\data.csv
# Deleted: ./Data\2024-05-07\data.csv
# Deleted: ./Data\2024-05-09\data.csv
# Deleted: ./Data\2024-05-12\data.csv
# Deleted: ./Data\2024-05-13\data.csv
# Deleted: ./Data\2024-05-14\data.csv
# Deleted: ./Data\2024-05-15\data.csv
# Deleted: ./Data\2024-05-16\data.csv
# Deleted: ./Data\2024-05-19\data.csv
# Deleted: ./Data\2024-05-20\data.csv
# Deleted: ./Data\2024-05-21\data.csv
# Deleted: ./Data\2024-05-22\data.csv
# Deleted: ./Data\2024-05-23\data.csv
# Deleted: ./Data\2024-05-26\data.csv
# Deleted: ./Data\2024-05-27\data.csv
# Deleted: ./Data\2024-05-28\data.csv
# Deleted: ./Data\2024-05-29\data.csv
# Deleted: ./Data\2024-05-30\data.csv
# Deleted: ./Data\2024-05-31\data.csv
# Deleted: ./Data\2024-06-01\data.csv
# Deleted: ./Data\2024-06-02\data.csv
# Deleted: ./Data\2024-06-03\data.csv
# Deleted: ./Data\2024-06-04\data.csv
# Deleted: ./Data\2024-06-05\data.csv
# Deleted: ./Data\2024-06-06\data.csv
# Deleted: ./Data\2024-06-07\data.csv
# Deleted: ./Data\2024-06-08\data.csv
# Deleted: ./Data\2024-06-09\data.csv
# Deleted: ./Data\2024-06-10\data.csv
# Deleted: ./Data\2024-06-11\data.csv
# Deleted: ./Data\2024-06-12\data.csv
# Deleted: ./Data\2024-06-13\data.csv
# Deleted: ./Data\2024-06-14\data.csv
# Deleted: ./Data\2024-06-15\data.csv
# Deleted: ./Data\2024-06-16\data.csv
# Deleted: ./Data\2024-06-17\data.csv
# Deleted: ./Data\2024-06-18\data.csv
# Deleted: ./Data\2024-06-19\data.csv
# Deleted: ./Data\2024-06-20\data.csv
# Deleted: ./Data\2024-06-21\data.csv
# Deleted: ./Data\2024-06-22\data.csv
